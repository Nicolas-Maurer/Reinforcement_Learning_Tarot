# %%
class Card :
    """ Represent the cards """
    
    def __init__(self, name, color, value, points, bout=False):
        self.name = name
        self.color = color
        self.value = value
        self.points = points
        self.bout = bout

# %%
one_of_diamond = Card(name="one_of_diamond", color="diamond", value=1, points=0.5)
two_of_diamond = Card(name="two_of_diamond", color="diamond", value=2, points=0.5)
three_of_diamond = Card(name="three_of_diamond", color="diamond", value=3, points=0.5)
four_of_diamond = Card(name="four_of_diamond", color="diamond", value=4, points=0.5)
five_of_diamond = Card(name="five_of_diamond", color="diamond", value=5, points=0.5)
six_of_diamond = Card(name="six_of_diamond", color="diamond", value=6, points=0.5)
seven_of_diamond = Card(name="seven_of_diamond", color="diamond", value=7, points=0.5)
eight_of_diamond = Card(name="eight_of_diamond", color="diamond", value=8, points=0.5)
nine_of_diamond = Card(name="nine_of_diamond", color="diamond", value=9, points=0.5)
ten_of_diamond = Card(name="ten_of_diamond", color="diamond", value=10, points=0.5)
jack_of_diamond = Card(name="jack_of_diamond", color="diamond", value=11, points=1.5)
knight_of_diamond = Card(name="knight_of_diamond", color="diamond", value=12, points=2.5)
queen_of_diamond = Card(name="queen_of_diamond", color="diamond", value=13, points=3.5)
king_of_diamond = Card(name="king_of_diamond", color="diamond", value=14, points=4.5)

one_of_spade = Card(name="one_of_spade", color="spade", value=1, points=0.5)
two_of_spade = Card(name="two_of_spade", color="spade", value=2, points=0.5)
three_of_spade = Card(name="three_of_spade", color="spade", value=3, points=0.5)
four_of_spade = Card(name="four_of_spade", color="spade", value=4, points=0.5)
five_of_spade = Card(name="five_of_spade", color="spade", value=5, points=0.5)
six_of_spade = Card(name="six_of_spade", color="spade", value=6, points=0.5)
seven_of_spade = Card(name="seven_of_spade", color="spade", value=7, points=0.5)
eight_of_spade = Card(name="eight_of_spade", color="spade", value=8, points=0.5)
nine_of_spade = Card(name="nine_of_spade", color="spade", value=9, points=0.5)
ten_of_spade = Card(name="ten_of_spade", color="spade", value=10, points=0.5)
jack_of_spade = Card(name="jack_of_spade", color="spade", value=11, points=1.5)
knight_of_spade = Card(name="knight_of_spade", color="spade", value=12, points=2.5)
queen_of_spade = Card(name="queen_of_spade", color="spade", value=13, points=3.5)
king_of_spade = Card(name="king_of_spade", color="spade", value=14, points=4.5)

one_of_heart = Card(name="one_of_heart", color="heart", value=1, points=0.5)
two_of_heart = Card(name="two_of_heart", color="heart", value=2, points=0.5)
three_of_heart = Card(name="three_of_heart", color="heart", value=3, points=0.5)
four_of_heart = Card(name="four_of_heart", color="heart", value=4, points=0.5)
five_of_heart = Card(name="five_of_heart", color="heart", value=5, points=0.5)
six_of_heart = Card(name="six_of_heart", color="heart", value=6, points=0.5)
seven_of_heart = Card(name="seven_of_heart", color="heart", value=7, points=0.5)
eight_of_heart = Card(name="eight_of_heart", color="heart", value=8, points=0.5)
nine_of_heart = Card(name="nine_of_heart", color="heart", value=9, points=0.5)
ten_of_heart = Card(name="ten_of_heart", color="heart", value=10, points=0.5)
jack_of_heart = Card(name="jack_of_heart", color="heart", value=11, points=1.5)
knight_of_heart = Card(name="knight_of_heart", color="heart", value=12, points=2.5)
queen_of_heart = Card(name="queen_of_heart", color="heart", value=13, points=3.5)
king_of_heart = Card(name="king_of_heart", color="heart", value=14, points=4.5)

one_of_club = Card(name="one_of_club", color="club", value=1, points=0.5)
two_of_club = Card(name="two_of_club", color="club", value=2, points=0.5)
three_of_club = Card(name="three_of_club", color="club", value=3, points=0.5)
four_of_club = Card(name="four_of_club", color="club", value=4, points=0.5)
five_of_club = Card(name="five_of_club", color="club", value=5, points=0.5)
six_of_club = Card(name="six_of_club", color="club", value=6, points=0.5)
seven_of_club = Card(name="seven_of_club", color="club", value=7, points=0.5)
eight_of_club = Card(name="eight_of_club", color="club", value=8, points=0.5)
nine_of_club = Card(name="nine_of_club", color="club", value=9, points=0.5)
ten_of_club = Card(name="ten_of_club", color="club", value=10, points=0.5)
jack_of_club = Card(name="jack_of_club", color="club", value=11, points=1.5)
knight_of_club = Card(name="knight_of_club", color="club", value=12, points=2.5)
queen_of_club = Card(name="queen_of_club", color="club", value=13, points=3.5)
king_of_club = Card(name="king_of_club", color="club", value=14, points=4.5)

one_of_trump = Card(name="un_of_trump", color="trump", value=1, points=4.5, bout=True)
two_of_trump = Card(name="two_of_trump", color="trump", value=2, points=0.5)
three_of_trump = Card(name="three_of_trump", color="trump", value=3, points=0.5)
four_of_trump = Card(name="four_of_trump", color="trump", value=4, points=0.5)
five_of_trump = Card(name="five_of_trump", color="trump", value=5, points=0.5)
six_of_trump = Card(name="six_of_trump", color="trump", value=6, points=0.5)
seven_of_trump = Card(name="seven_of_trump", color="trump", value=7, points=0.5)
eight_of_trump = Card(name="eight_of_trump", color="trump", value=8, points=0.5)
nine_of_trump = Card(name="nine_of_trump", color="trump", value=9, points=0.5)
ten_of_trump = Card(name="ten_of_trump", color="trump", value=10, points=0.5)
eleven_of_trump = Card(name="eleven_of_trump", color="trump", value=11, points=0.5)
twelve_of_trump = Card(name="twelve_of_trump", color="trump", value=12, points=0.5)
thirteen_of_trump = Card(name="thirteen_of_trump", color="trump", value=13, points=0.5)
fourteen_of_trump = Card(name="fourteen_of_trump", color="trump", value=14, points=0.5)
fifteen_of_trump = Card(name="fifteen_of_trump", color="trump", value=15, points=0.5)
sixteen_of_trump = Card(name="sixteen_of_trump", color="trump", value=16, points=0.5)
seventeen_of_trump = Card(name="seventeen_of_trump", color="trump", value=17, points=0.5)
eighteen_of_trump = Card(name="eighteen_of_trump", color="trump", value=18, points=0.5)
nineteen_of_trump = Card(name="nineteen_of_trump", color="trump", value=19, points=0.5)
twenty_of_trump = Card(name="twenty_of_trump", color="trump", value=20, points=0.5)
twenty_one_of_trump = Card(name="twenty_one_of_trump", color="trump", value=21, points=4.5, bout=True)

excuse = Card(name="excuse", color="Joker", value=0, points=4.5, bout=True)

# %%
deck = [one_of_diamond, two_of_diamond, three_of_diamond, four_of_diamond, five_of_diamond, six_of_diamond, seven_of_diamond,
        eight_of_diamond, nine_of_diamond, ten_of_diamond, jack_of_diamond, knight_of_diamond, queen_of_diamond,
        king_of_diamond, one_of_spade, two_of_spade, three_of_spade, four_of_spade, five_of_spade, six_of_spade, 
        seven_of_spade, eight_of_spade, nine_of_spade, ten_of_spade, jack_of_spade, knight_of_spade, queen_of_spade,
        king_of_spade, one_of_heart, two_of_heart, three_of_heart, four_of_heart, five_of_heart, six_of_heart, 
        seven_of_heart, eight_of_heart, nine_of_heart, ten_of_heart, jack_of_heart, knight_of_heart, queen_of_heart,
        king_of_heart, one_of_club, two_of_club, three_of_club, four_of_club, five_of_club, six_of_club, seven_of_club,
        eight_of_club, nine_of_club, ten_of_club, jack_of_club, knight_of_club, queen_of_club, king_of_club, one_of_trump,
        two_of_trump, three_of_trump, four_of_trump, five_of_trump, six_of_trump, seven_of_trump, eight_of_trump, 
        nine_of_trump, ten_of_trump, eleven_of_trump, twelve_of_trump, thirteen_of_trump, fourteen_of_trump, 
        fifteen_of_trump, sixteen_of_trump, seventeen_of_trump, eighteen_of_trump, nineteen_of_trump, twenty_of_trump,
        twenty_one_of_trump, excuse]
