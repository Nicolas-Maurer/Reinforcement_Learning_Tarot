# %%
class Carte :
    """ Représente une carte à jouer """
    
    def __init__(self, name, couleur, valeur, points, bout=False):
        self.name = name
        self.couleur = couleur
        self.valeur = valeur
        self.points = points
        self.bout = bout

# %%
as_carreau = Carte(name="as_de_carreau", couleur="carreau", valeur=1, points=0.5)
deux_carreau = Carte(name="deux_de_carreau", couleur="carreau", valeur=2, points=0.5)
trois_carreau = Carte(name="trois_de_carreau", couleur="carreau", valeur=3, points=0.5)
quatre_carreau = Carte(name="quatre_de_carreau", couleur="carreau", valeur=4, points=0.5)
cinq_carreau = Carte(name="cinq_de_carreau", couleur="carreau", valeur=5, points=0.5)
six_carreau = Carte(name="six_de_carreau", couleur="carreau", valeur=6, points=0.5)
sept_carreau = Carte(name="sept_de_carreau", couleur="carreau", valeur=7, points=0.5)
huit_carreau = Carte(name="huit_de_carreau", couleur="carreau", valeur=8, points=0.5)
neuf_carreau = Carte(name="neuf_de_carreau", couleur="carreau", valeur=9, points=0.5)
dix_carreau = Carte(name="dix_de_carreau", couleur="carreau", valeur=10, points=0.5)
valet_carreau = Carte(name="valet_de_carreau", couleur="carreau", valeur=11, points=1.5)
cavalier_carreau = Carte(name="cavalier_de_carreau", couleur="carreau", valeur=12, points=2.5)
dame_carreau = Carte(name="dame_de_carreau", couleur="carreau", valeur=13, points=3.5)
roi_carreau = Carte(name="roi_de_carreau", couleur="carreau", valeur=14, points=4.5)

as_pique = Carte(name="as_de_pique", couleur="pique", valeur=1, points=0.5)
deux_pique = Carte(name="deux_de_pique", couleur="pique", valeur=2, points=0.5)
trois_pique = Carte(name="trois_de_pique", couleur="pique", valeur=3, points=0.5)
quatre_pique = Carte(name="quatre_de_pique", couleur="pique", valeur=4, points=0.5)
cinq_pique = Carte(name="cinq_de_pique", couleur="pique", valeur=5, points=0.5)
six_pique = Carte(name="six_de_pique", couleur="pique", valeur=6, points=0.5)
sept_pique = Carte(name="sept_de_pique", couleur="pique", valeur=7, points=0.5)
huit_pique = Carte(name="huit_de_pique", couleur="pique", valeur=8, points=0.5)
neuf_pique = Carte(name="neuf_de_pique", couleur="pique", valeur=9, points=0.5)
dix_pique = Carte(name="dix_de_pique", couleur="pique", valeur=10, points=0.5)
valet_pique = Carte(name="valet_de_pique", couleur="pique", valeur=11, points=1.5)
cavalier_pique = Carte(name="cavalier_de_pique", couleur="pique", valeur=12, points=2.5)
dame_pique = Carte(name="dame_de_pique", couleur="pique", valeur=13, points=3.5)
roi_pique = Carte(name="roi_de_pique", couleur="pique", valeur=14, points=4.5)

as_coeur = Carte(name="as_de_coeur", couleur="coeur", valeur=1, points=0.5)
deux_coeur = Carte(name="deux_de_coeur", couleur="coeur", valeur=2, points=0.5)
trois_coeur = Carte(name="trois_de_coeur", couleur="coeur", valeur=3, points=0.5)
quatre_coeur = Carte(name="quatre_de_coeur", couleur="coeur", valeur=4, points=0.5)
cinq_coeur = Carte(name="cinq_de_coeur", couleur="coeur", valeur=5, points=0.5)
six_coeur = Carte(name="six_de_coeur", couleur="coeur", valeur=6, points=0.5)
sept_coeur = Carte(name="sept_de_coeur", couleur="coeur", valeur=7, points=0.5)
huit_coeur = Carte(name="huit_de_coeur", couleur="coeur", valeur=8, points=0.5)
neuf_coeur = Carte(name="neuf_de_coeur", couleur="coeur", valeur=9, points=0.5)
dix_coeur = Carte(name="dix_de_coeur", couleur="coeur", valeur=10, points=0.5)
valet_coeur = Carte(name="valet_de_coeur", couleur="coeur", valeur=11, points=1.5)
cavalier_coeur = Carte(name="cavalier_de_coeur", couleur="coeur", valeur=12, points=2.5)
dame_coeur = Carte(name="dame_de_coeur", couleur="coeur", valeur=13, points=3.5)
roi_coeur = Carte(name="roi_de_coeur", couleur="coeur", valeur=14, points=4.5)

as_trefle = Carte(name="as_de_trefle", couleur="trefle", valeur=1, points=0.5)
deux_trefle = Carte(name="deux_de_trefle", couleur="trefle", valeur=2, points=0.5)
trois_trefle = Carte(name="trois_de_trefle", couleur="trefle", valeur=3, points=0.5)
quatre_trefle = Carte(name="quatre_de_trefle", couleur="trefle", valeur=4, points=0.5)
cinq_trefle = Carte(name="cinq_de_trefle", couleur="trefle", valeur=5, points=0.5)
six_trefle = Carte(name="six_de_trefle", couleur="trefle", valeur=6, points=0.5)
sept_trefle = Carte(name="sept_de_trefle", couleur="trefle", valeur=7, points=0.5)
huit_trefle = Carte(name="huit_de_trefle", couleur="trefle", valeur=8, points=0.5)
neuf_trefle = Carte(name="neuf_de_trefle", couleur="trefle", valeur=9, points=0.5)
dix_trefle = Carte(name="dix_de_trefle", couleur="trefle", valeur=10, points=0.5)
valet_trefle = Carte(name="valet_de_trefle", couleur="trefle", valeur=11, points=1.5)
cavalier_trefle = Carte(name="cavalier_de_trefle", couleur="trefle", valeur=12, points=2.5)
dame_trefle = Carte(name="dame_de_trefle", couleur="trefle", valeur=13, points=3.5)
roi_trefle = Carte(name="roi_de_trefle", couleur="trefle", valeur=14, points=4.5)

un_atout = Carte(name="un_d'atout", couleur="atout", valeur=1, points=4.5, bout=True)
deux_atout = Carte(name="deux_d'atout", couleur="atout", valeur=2, points=0.5)
trois_atout = Carte(name="trois_d'atout", couleur="atout", valeur=3, points=0.5)
quatre_atout = Carte(name="quatre_d'atout", couleur="atout", valeur=4, points=0.5)
cinq_atout = Carte(name="cinq_d'atout", couleur="atout", valeur=5, points=0.5)
six_atout = Carte(name="six_d'atout", couleur="atout", valeur=6, points=0.5)
sept_atout = Carte(name="sept_d'atout", couleur="atout", valeur=7, points=0.5)
huit_atout = Carte(name="huit_d'atout", couleur="atout", valeur=8, points=0.5)
neuf_atout = Carte(name="neuf_d'atout", couleur="atout", valeur=9, points=0.5)
dix_atout = Carte(name="dix_d'atout", couleur="atout", valeur=10, points=0.5)
onze_atout = Carte(name="onze_d'atout", couleur="atout", valeur=11, points=0.5)
douze_atout = Carte(name="douze_d'atout", couleur="atout", valeur=12, points=0.5)
treize_atout = Carte(name="treize_d'atout", couleur="atout", valeur=13, points=0.5)
quatorze_atout = Carte(name="quatorze_d'atout", couleur="atout", valeur=14, points=0.5)
quinze_atout = Carte(name="quinze_d'atout", couleur="atout", valeur=15, points=0.5)
seize_atout = Carte(name="seize_d'atout", couleur="atout", valeur=16, points=0.5)
dix_sept_atout = Carte(name="dix_sept_d'atout", couleur="atout", valeur=17, points=0.5)
dix_huit_atout = Carte(name="dix_huit_d'atout", couleur="atout", valeur=18, points=0.5)
dix_neuf_atout = Carte(name="dix_neuf_d'atout", couleur="atout", valeur=19, points=0.5)
vingt_atout = Carte(name="vingt_d'atout", couleur="atout", valeur=20, points=0.5)
vingt_un_atout = Carte(name="vingt_et_un_d'atout", couleur="atout", valeur=21, points=4.5, bout=True)

excuse = Carte(name="excuse", couleur="Joker", valeur=0, points=4.5, bout=True)

# %%
deck = [as_carreau, deux_carreau, trois_carreau, quatre_carreau, cinq_carreau, six_carreau, sept_carreau, huit_carreau,
        neuf_carreau, dix_carreau, valet_carreau, cavalier_carreau, dame_carreau, roi_carreau, as_pique, deux_pique,
        trois_pique, quatre_pique, cinq_pique, six_pique, sept_pique, huit_pique, neuf_pique, dix_pique,
        valet_pique, cavalier_pique, dame_pique, roi_pique, as_coeur, deux_coeur, trois_coeur, quatre_coeur,
        cinq_coeur, six_coeur, sept_coeur, huit_coeur, neuf_coeur, dix_coeur, valet_coeur, cavalier_coeur,
        dame_coeur, roi_coeur, as_trefle, deux_trefle, trois_trefle, quatre_trefle, cinq_trefle, six_trefle,
        sept_trefle, huit_trefle, neuf_trefle, dix_trefle, valet_trefle, cavalier_trefle, dame_trefle, roi_trefle, 
        un_atout, deux_atout, trois_atout, quatre_atout, cinq_atout, six_atout, sept_atout, huit_atout, 
        neuf_atout, dix_atout,onze_atout, douze_atout, treize_atout, quatorze_atout, quinze_atout, seize_atout,
        dix_sept_atout, dix_huit_atout, dix_neuf_atout, vingt_atout, vingt_un_atout, excuse]
