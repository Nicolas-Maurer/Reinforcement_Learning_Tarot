# %%
class Card :
    """ Represent the cards """
    
    def __init__(self, name, color, value, points, bout=False):
        self.name = name
        self.color = color
        self.value = value
        self.points = points
        self.bout = bout

# %%
one_diamonds = Card(name="one_of_diamonds", color="diamonds", value=1, points=0.5)
two_diamonds = Card(name="two_of_diamonds", color="diamonds", value=2, points=0.5)
three_diamonds = Card(name="three_of_diamonds", color="diamonds", value=3, points=0.5)
four_diamonds = Card(name="four_of_diamonds", color="diamonds", value=4, points=0.5)
five_diamonds = Card(name="five_of_diamonds", color="diamonds", value=5, points=0.5)
six_diamonds = Card(name="six_of_diamonds", color="diamonds", value=6, points=0.5)
seven_diamonds = Card(name="seven_of_diamonds", color="diamonds", value=7, points=0.5)
eight_diamonds = Card(name="eight_of_diamonds", color="diamonds", value=8, points=0.5)
nine_diamonds = Card(name="nine_of_diamonds", color="diamonds", value=9, points=0.5)
ten_diamonds = Card(name="ten_of_diamonds", color="diamonds", value=10, points=0.5)
jack_diamonds = Card(name="jack_of_diamonds", color="diamonds", value=11, points=1.5)
knight_diamonds = Card(name="knight_of_diamonds", color="diamonds", value=12, points=2.5)
queen_diamonds = Card(name="queen_of_diamonds", color="diamonds", value=13, points=3.5)
king_diamonds = Card(name="king_of_diamonds", color="diamonds", value=14, points=4.5)

one_spade = Card(name="one_of_spade", color="spade", value=1, points=0.5)
two_spade = Card(name="two_of_spade", color="spade", value=2, points=0.5)
three_spade = Card(name="three_of_spade", color="spade", value=3, points=0.5)
four_spade = Card(name="four_of_spade", color="spade", value=4, points=0.5)
five_spade = Card(name="five_of_spade", color="spade", value=5, points=0.5)
six_spade = Card(name="six_of_spade", color="spade", value=6, points=0.5)
seven_spade = Card(name="seven_of_spade", color="spade", value=7, points=0.5)
eight_spade = Card(name="eight_of_spade", color="spade", value=8, points=0.5)
nine_spade = Card(name="nine_of_spade", color="spade", value=9, points=0.5)
ten_spade = Card(name="ten_of_spade", color="spade", value=10, points=0.5)
jack_spade = Card(name="jack_of_spade", color="spade", value=11, points=1.5)
knight_spade = Card(name="knight_of_spade", color="spade", value=12, points=2.5)
queen_spade = Card(name="queen_of_spade", color="spade", value=13, points=3.5)
king_spade = Card(name="king_of_spade", color="spade", value=14, points=4.5)

one_heart = Card(name="one_of_heart", color="heart", value=1, points=0.5)
two_heart = Card(name="two_of_heart", color="heart", value=2, points=0.5)
three_heart = Card(name="three_of_heart", color="heart", value=3, points=0.5)
four_heart = Card(name="four_of_heart", color="heart", value=4, points=0.5)
five_heart = Card(name="five_of_heart", color="heart", value=5, points=0.5)
six_heart = Card(name="six_of_heart", color="heart", value=6, points=0.5)
seven_heart = Card(name="seven_of_heart", color="heart", value=7, points=0.5)
eight_heart = Card(name="eight_of_heart", color="heart", value=8, points=0.5)
nine_heart = Card(name="nine_of_heart", color="heart", value=9, points=0.5)
ten_heart = Card(name="ten_of_heart", color="heart", value=10, points=0.5)
jack_heart = Card(name="jack_of_heart", color="heart", value=11, points=1.5)
knight_heart = Card(name="knight_of_heart", color="heart", value=12, points=2.5)
queen_heart = Card(name="queen_of_heart", color="heart", value=13, points=3.5)
king_heart = Card(name="king_of_heart", color="heart", value=14, points=4.5)

one_club = Card(name="one_of_club", color="club", value=1, points=0.5)
two_club = Card(name="two_of_club", color="club", value=2, points=0.5)
three_club = Card(name="three_of_club", color="club", value=3, points=0.5)
four_club = Card(name="four_of_club", color="club", value=4, points=0.5)
five_club = Card(name="five_of_club", color="club", value=5, points=0.5)
six_club = Card(name="six_of_club", color="club", value=6, points=0.5)
seven_club = Card(name="seven_of_club", color="club", value=7, points=0.5)
eight_club = Card(name="eight_of_club", color="club", value=8, points=0.5)
nine_club = Card(name="nine_of_club", color="club", value=9, points=0.5)
ten_club = Card(name="ten_of_club", color="club", value=10, points=0.5)
jack_club = Card(name="jack_of_club", color="club", value=11, points=1.5)
knight_club = Card(name="knight_of_club", color="club", value=12, points=2.5)
queen_club = Card(name="queen_of_club", color="club", value=13, points=3.5)
king_club = Card(name="king_of_club", color="club", value=14, points=4.5)

un_trump = Card(name="un_of_trump", color="trump", value=1, points=4.5, bout=True)
two_trump = Card(name="two_of_trump", color="trump", value=2, points=0.5)
three_trump = Card(name="three_of_trump", color="trump", value=3, points=0.5)
four_trump = Card(name="four_of_trump", color="trump", value=4, points=0.5)
five_trump = Card(name="five_of_trump", color="trump", value=5, points=0.5)
six_trump = Card(name="six_of_trump", color="trump", value=6, points=0.5)
seven_trump = Card(name="seven_of_trump", color="trump", value=7, points=0.5)
eight_trump = Card(name="eight_of_trump", color="trump", value=8, points=0.5)
nine_trump = Card(name="nine_of_trump", color="trump", value=9, points=0.5)
ten_trump = Card(name="ten_of_trump", color="trump", value=10, points=0.5)
eleven_trump = Card(name="eleven_of_trump", color="trump", value=11, points=0.5)
twelve_trump = Card(name="twelve_of_trump", color="trump", value=12, points=0.5)
thirteen_trump = Card(name="thirteen_of_trump", color="trump", value=13, points=0.5)
fourteen_trump = Card(name="fourteen_of_trump", color="trump", value=14, points=0.5)
fifteen_trump = Card(name="fifteen_of_trump", color="trump", value=15, points=0.5)
sixteen_trump = Card(name="sixteen_of_trump", color="trump", value=16, points=0.5)
seventeen_trump = Card(name="seventeen_of_trump", color="trump", value=17, points=0.5)
eighteen_trump = Card(name="eighteen_of_trump", color="trump", value=18, points=0.5)
nineteen_trump = Card(name="nineteen_of_trump", color="trump", value=19, points=0.5)
twenty_trump = Card(name="twenty_of_trump", color="trump", value=20, points=0.5)
twenty_one_trump = Card(name="twenty_one_of_trump", color="trump", value=21, points=4.5, bout=True)

excuse = Card(name="excuse", color="Joker", value=0, points=4.5, bout=True)

# %%
deck = [one_diamonds, two_diamonds, three_diamonds, four_diamonds, five_diamonds, six_diamonds, seven_diamonds, eight_diamonds,
        nine_diamonds, ten_diamonds, jack_diamonds, knight_diamonds, queen_diamonds, king_diamonds, one_spade, two_spade,
        three_spade, four_spade, five_spade, six_spade, seven_spade, eight_spade, nine_spade, ten_spade,
        jack_spade, knight_spade, queen_spade, king_spade, one_heart, two_heart, three_heart, four_heart,
        five_heart, six_heart, seven_heart, eight_heart, nine_heart, ten_heart, jack_heart, knight_heart,
        queen_heart, king_heart, one_club, two_club, three_club, four_club, five_club, six_club,
        seven_club, eight_club, nine_club, ten_club, jack_club, knight_club, queen_club, king_club, 
        un_trump, two_trump, three_trump, four_trump, five_trump, six_trump, seven_trump, eight_trump, 
        nine_trump, ten_trump,eleven_trump, twelve_trump, thirteen_trump, fourteen_trump, fifteen_trump, sixteen_trump,
        ten_seven_trump, ten_eight_trump, ten_nine_trump, vingt_trump, vingt_un_trump, excuse]
